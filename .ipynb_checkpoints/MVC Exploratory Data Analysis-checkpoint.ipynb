# %% [markdown]
# # Scope
#
# MVC_individuals = every person involved is a record - repeat event #
# MVC_ events = every event is a record - NO repeat event #
#
# 1. Exploratory Data Analysis
#
# 2. Location Analysis
#     a. Most Common Area?
#     b. Most Common Road Type/Environment?
#     c. Interactions between smaller vehicles & larger vehicles
#
# 3. Conditions Analysis
#     a. Light
#     b. Road Condition
#     c. Visibility
#     d. Type of Impact
#     e. Most likely individual type to be KSI - driver, passenger, bicycle, motorcycle
#
# 4. Causes/Driver Action Analysis
#     a. Speeding
#     b. Agression
#     c. Alcohol
#     d. Red Light
#     c. Medical/Disability
#     e. Driver Age
#
# 5. Statistical significance to results? Is the observed data due to chance, or some other factor?
#
# 6. Principal Component Analysis - which variables contain the most predictive value?
#
# 7. Machine Learning Prediction Model...

# %%
#https://data.torontopolice.on.ca/datasets/TorontoPS::ksi/about

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

mvc = pd.read_csv('KSI_MVC.csv',low_memory=False)

# %%
mvc.head()
# Out:
#              X            Y   INDEX_    ACCNUM  YEAR                    DATE  \
# 0 -8844610.729  5412413.888  3387730  892658.0  2006  2006/03/11 05:00:00+00
# 1 -8844610.729  5412413.888  3387731  892658.0  2006  2006/03/11 05:00:00+00
# 2 -8816479.848  5434843.389  3388101  892810.0  2006  2006/03/11 05:00:00+00
# 3 -8829728.092  5419070.899  3389067  893184.0  2006  2006/01/01 05:00:00+00
# 4 -8816479.848  5434843.389  3388102  892810.0  2006  2006/03/11 05:00:00+00
#
#    TIME          STREET1         STREET2 OFFSET  ... AG_DRIV REDLIGHT  \
# 0   852       BLOOR ST W     DUNDAS ST W    NaN  ...     Yes      NaN
# 1   852       BLOOR ST W     DUNDAS ST W    NaN  ...     Yes      NaN
# 2   915  MORNINGSIDE AVE  SHEPPARD AVE E    NaN  ...     Yes      Yes
# 3   236     WOODBINE AVE     O CONNOR DR    NaN  ...     Yes      NaN
# 4   915  MORNINGSIDE AVE  SHEPPARD AVE E    NaN  ...     Yes      Yes
#
#    ALCOHOL  DISABILITY  HOOD_158 NEIGHBOURHOOD_158 HOOD_140  \
# ...

# %%
mvc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18194 entries, 0 to 18193
# Data columns (total 57 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X                  18194 non-null  float64
#  1   Y                  18194 non-null  float64
#  2   INDEX_             18194 non-null  int64
#  3   ACCNUM             13264 non-null  float64
#  4   YEAR               18194 non-null  int64
#  5   DATE               18194 non-null  object
#  6   TIME               18194 non-null  int64
#  7   STREET1            18194 non-null  object
#  8   STREET2            16510 non-null  object
#  9   OFFSET             3402 non-null   object
#  10  ROAD_CLASS         17818 non-null  object
#  11  DISTRICT           18089 non-null  object
#  12  WARDNUM            17332 non-null  float64
#  13  LATITUDE           18194 non-null  float64
#  14  LONGITUDE          18194 non-null  float64
#  15  LOCCOORD           18099 non-null  object
# ...

# %%
mvc.describe(include='all')
# Out:
#                    X             Y        INDEX_        ACCNUM          YEAR  \
# count   1.819400e+04  1.819400e+04  1.819400e+04  1.326400e+04  18194.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean   -8.838345e+06  5.420748e+06  3.818870e+07  4.248444e+08   2012.934869
# std     1.162533e+04  8.682160e+03  3.726463e+07  1.065503e+09      4.754258
# min    -8.865305e+06  5.402162e+06  3.363207e+06  2.530100e+04   2006.000000
# 25%    -8.846591e+06  5.413242e+06  5.391370e+06  1.021229e+06   2009.000000
# 50%    -8.838448e+06  5.419556e+06  7.644612e+06  1.197308e+06   2012.000000
# 75%    -8.829671e+06  5.427813e+06  8.078261e+07  1.365020e+06   2017.000000
# max    -8.807929e+06  5.443099e+06  8.170606e+07  4.008024e+09   2022.000000
#
# ...

# %%
mvc.duplicated().value_counts()
# Out:
# False    18194
# dtype: int64

# %%
mvc.columns.to_list()
# Out:
# ['X',
#  'Y',
#  'INDEX_',
#  'ACCNUM',
#  'YEAR',
#  'DATE',
#  'TIME',
#  'STREET1',
#  'STREET2',
#  'OFFSET',
#  'ROAD_CLASS',
#  'DISTRICT',
#  'WARDNUM',
#  'LATITUDE',
#  'LONGITUDE',
#  'LOCCOORD',
#  'ACCLOC',
#  'TRAFFCTL',
#  'VISIBILITY',
#  'LIGHT',
#  'RDSFCOND',
#  'ACCLASS',
#  'IMPACTYPE',
#  'INVTYPE',
#  'INVAGE',
#  'INJURY',
#  'FATAL_NO',
#  'INITDIR',
#  'VEHTYPE',
#  'MANOEUVER',
#  'DRIVACT',
#  'DRIVCOND',
#  'PEDTYPE',
#  'PEDACT',
#  'PEDCOND',
#  'CYCLISTYPE',
#  'CYCACT',
#  'CYCCOND',
#  'PEDESTRIAN',
#  'CYCLIST',
#  'AUTOMOBILE',
#  'MOTORCYCLE',
#  'TRUCK',
#  'TRSN_CITY_VEH',
#  'EMERG_VEH',
#  'PASSENGER',
#  'SPEEDING',
#  'AG_DRIV',
#  'REDLIGHT',
#  'ALCOHOL',
#  'DISABILITY',
#  'HOOD_158',
#  'NEIGHBOURHOOD_158',
#  'HOOD_140',
#  'NEIGHBOURHOOD_140',
#  'DIVISION',
#  'ObjectId']

# %%
mvc = mvc[[
 'ACCNUM',
 'YEAR',
 'DATE',
 'TIME',
 'STREET1',
 'STREET2',
 'OFFSET',
 'ROAD_CLASS',
 'DISTRICT', 
'NEIGHBOURHOOD_158',
 'LOCCOORD',
 'ACCLOC',
 'TRAFFCTL',
 'VISIBILITY',
 'LIGHT',
 'RDSFCOND',
 'ACCLASS',
 'IMPACTYPE',
 'INVTYPE',
 'INVAGE',
 'INJURY',
 'INITDIR',
 'VEHTYPE',
 'MANOEUVER',
 'DRIVACT',
 'DRIVCOND',
 'PEDTYPE',
 'PEDACT',
 'PEDCOND',
 'CYCLISTYPE',
 'CYCACT',
 'CYCCOND',
 'PEDESTRIAN',
 'CYCLIST',
 'AUTOMOBILE',
 'MOTORCYCLE',
 'TRUCK',
 'TRSN_CITY_VEH',
 'EMERG_VEH',
 'PASSENGER',
 'SPEEDING',
 'AG_DRIV',
 'REDLIGHT',
 'ALCOHOL',
 'DISABILITY']]

# %%
mvc.rename(columns = {
 'ACCNUM':'event',
 'YEAR':'year',
 'DATE':'date',
 'TIME':'time',
 'STREET1':'street_1',
 'STREET2':'street_2',
 'OFFSET':'street_offset',
 'ROAD_CLASS':'road_class',
 'DISTRICT':'district', 
'NEIGHBOURHOOD_158':'neighbourhood',
 'LOCCOORD':'coordinates',
 'ACCLOC':'location',
 'TRAFFCTL':'traffic_control',
 'VISIBILITY':'visibility',
 'LIGHT':'light',
 'RDSFCOND':'road_condition',
 'ACCLASS':'classification',
 'IMPACTYPE':'impact',
 'INVTYPE':'involvement',
 'INVAGE':'age',
 'INJURY':'injury',
 'INITDIR':'travel_direction',
 'VEHTYPE':'vehicle',
 'MANOEUVER':'manoeuver',
 'DRIVACT':'driver_action',
 'DRIVCOND':'driver_condition',
 'PEDTYPE':'ped_crash_type',
 'PEDACT':'ped_action',
 'PEDCOND':'ped_condition',
 'CYCLISTYPE':'cycle_crash_type',
 'CYCACT':'cycle_action',
 'CYCCOND':'cycle_condition',
 'PEDESTRIAN':'involved_ped',
 'CYCLIST':'involved_cycle',
 'AUTOMOBILE':'involved_car',
 'MOTORCYCLE':'involved_moto',
 'TRUCK':'involved_truck',
 'TRSN_CITY_VEH':'involved_transit_city',
 'EMERG_VEH':'involved_emerg',
 'PASSENGER':'involved_passenger',
 'SPEEDING':'speeding',
 'AG_DRIV':'aggresive_distracted',
 'REDLIGHT':'redlight',
 'ALCOHOL':'alcohol',
 'DISABILITY':'medical_disability'}, inplace=True)
mvc.head()
# Out:
#       event  year                    date  time         street_1  \
# 0  892658.0  2006  2006/03/11 05:00:00+00   852       BLOOR ST W
# 1  892658.0  2006  2006/03/11 05:00:00+00   852       BLOOR ST W
# 2  892810.0  2006  2006/03/11 05:00:00+00   915  MORNINGSIDE AVE
# 3  893184.0  2006  2006/01/01 05:00:00+00   236     WOODBINE AVE
# 4  892810.0  2006  2006/03/11 05:00:00+00   915  MORNINGSIDE AVE
#
#          street_2 street_offset      road_class               district  \
# 0     DUNDAS ST W           NaN  Major Arterial  Toronto and East York
# 1     DUNDAS ST W           NaN  Major Arterial  Toronto and East York
# 2  SHEPPARD AVE E           NaN  Major Arterial            Scarborough
# 3     O CONNOR DR           NaN  Major Arterial  Toronto and East York
# 4  SHEPPARD AVE E           NaN  Major Arterial            Scarborough
#
#       neighbourhood  ... involved_moto involved_truck involved_transit_city  \
# ...

# %% [markdown]
# # Data Cleaning
#
# go through every columns; datatype, unique, nulls, etc

# %%
mvc.event.describe()
# Out:
# count    1.326400e+04
# mean     4.248444e+08
# std      1.065503e+09
# min      2.530100e+04
# 25%      1.021229e+06
# 50%      1.197308e+06
# 75%      1.365020e+06
# max      4.008024e+09
# Name: event, dtype: float64

# %%
mvc.event = mvc.event.astype('object')

# %%
mvc.event.describe()
# Out:
# count       13264.0
# unique       4629.0
# top       1311498.0
# freq           19.0
# Name: event, dtype: float64

# %%
mvc.event.isna().value_counts()
# Out:
# False    13264
# True      4930
# Name: event, dtype: int64

# %%
mvc = mvc.fillna(value={'event':'blank'})

# %%
mvc.event.isna().value_counts()
# Out:
# False    18194
# Name: event, dtype: int64

# %%
mvc[mvc.event == 'blank'].groupby('year').count()
# Out:
#       event  date  time  street_1  street_2  street_offset  road_class  \
# year
# 2013      2     2     2         2         2              0           2
# 2014      2     2     2         2         2              0           2
# 2015    929   929   929       929       800            437         911
# 2016   1006  1006  1006      1006       914            433         991
# 2017    979   979   979       979       888            504         962
# 2018   1072  1072  1072      1072       939            482        1068
# 2019    940   940   940       940       845            421         940
#
#       district  neighbourhood  coordinates  ...  involved_moto  \
# year                                        ...
# 2013         2              2            2  ...              0
# 2014         2              2            2  ...              0
# 2015       922            929          929  ...             92
# 2016      1006           1006         1006  ...            115
# ...

# %% [markdown]
# Since the event number is not unique and repeats year over year, this is not something I'm concerned with. The blanks will not affect my analysis

# %%
mvc.year.describe()
# Out:
# count    18194.000000
# mean      2012.934869
# std          4.754258
# min       2006.000000
# 25%       2009.000000
# 50%       2012.000000
# 75%       2017.000000
# max       2022.000000
# Name: year, dtype: float64

# %%
mvc.year.unique()
# Out:
# array([2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016,
#        2017, 2018, 2019, 2020, 2021, 2022])

# %%
mvc.year.isna().value_counts()
# Out:
# False    18194
# Name: year, dtype: int64

# %% [markdown]
# How to deal with date & time??????
